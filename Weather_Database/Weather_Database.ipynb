# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from config import weather_api_key
import time
from datetime import datetime
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 749

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65349ca7dbb1f0d2bb1dcae524069dcc

# %%
city_url = url + "&q=" + city.replace(" ", "+")
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': -73.4, 'lat': 18.2833},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 77.94,
#   'feels_like': 78.85,
#   'temp_min': 77.94,
#   'temp_max': 77.94,
#   'pressure': 1014,
#   'humidity': 73,
#   'sea_level': 1014,
#   'grnd_level': 1012},
#  'visibility': 10000,
#  'wind': {'speed': 10.18, 'deg': 1, 'gust': 12.5},
#  'clouds': {'all': 72},
#  'dt': 1648422321,
#  'sys': {'country': 'HT', 'sunrise': 1648378310, 'sunset': 1648422352},
#  'timezone': -14400,
#  'id': 3731095,
#  'name': 'Aquin',
#  'cod': 200}

# %%
city_weather["weather"][0]["description"]
# Out:
# 'broken clouds'

# %%
# Create an empty list to hold the weather data 
city_data = []
#print the beginning of the logging
print("Begging Data Retrieval   ")
print("-------------------------")

# Create counters
record_count = 1 
set_count = 1

# Lopp through all the cities in our list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1 
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city 
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count 
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Begging Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | dikson
# Processing Record 8 of Set 1 | naze
# Processing Record 9 of Set 1 | wilmington
# Processing Record 10 of Set 1 | port elizabeth
# Processing Record 11 of Set 1 | victoria
# Processing Record 12 of Set 1 | port alfred
# Processing Record 13 of Set 1 | brae
# Processing Record 14 of Set 1 | sarankhola
# Processing Record 15 of Set 1 | airai
# Processing Record 16 of Set 1 | meadow lake
# Processing Record 17 of Set 1 | mahebourg
# Processing Record 18 of Set 1 | bela
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | boddam
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | kruisfontein
# Processing Record 23 of Set 1 | yantal
# Processing Record 24 of Set 1 | chuy
# Processing Record 25 of Set 1 | bluff
# Processing Record 26 of Set 1 | kikwit
# Processing Record 27 of Set 1 | santo antonio do ica
# Processing Record 28 of Set 1 | saldanha
# Processing Record 29 of Set 1 | pavilosta
# Processing Record 30 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 1 | bredasdorp
# Processing Record 32 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 1 | veshenskaya
# Processing Record 35 of Set 1 | redencao
# Processing Record 36 of Set 1 | praia da vitoria
# Processing Record 37 of Set 1 | mar del plata
# Processing Record 38 of Set 1 | melilla
# Processing Record 39 of Set 1 | saint-philippe
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | yellowknife
# Processing Record 42 of Set 1 | kodiak
# Processing Record 43 of Set 1 | sao filipe
# Processing Record 44 of Set 1 | nanortalik
# Processing Record 45 of Set 1 | coquimbo
# Processing Record 46 of Set 1 | barrow
# Processing Record 47 of Set 1 | ziro
# Processing Record 48 of Set 1 | ngorongoro
# Processing Record 49 of Set 1 | tuktoyaktuk
# Processing Record 50 of Set 1 | saskylakh
# Processing Record 1 of Set 2 | puerto ayora
# Processing Record 2 of Set 2 | buritizeiro
# Processing Record 3 of Set 2 | bilibino
# Processing Record 4 of Set 2 | flinders
# Processing Record 5 of Set 2 | beringovskiy
# Processing Record 6 of Set 2 | avarua
# Processing Record 7 of Set 2 | tasiilaq
# Processing Record 8 of Set 2 | teahupoo
# Processing Record 9 of Set 2 | ponta do sol
# Processing Record 10 of Set 2 | esperance
# Processing Record 11 of Set 2 | hithadhoo
# Processing Record 12 of Set 2 | camana
# Processing Record 13 of Set 2 | kalomo
# City not found. Skipping...
# Processing Record 14 of Set 2 | shakawe
# Processing Record 15 of Set 2 | viransehir
# Processing Record 16 of Set 2 | avdon
# Processing Record 17 of Set 2 | svetlyy
# Processing Record 18 of Set 2 | kiama
# Processing Record 19 of Set 2 | busselton
# Processing Record 20 of Set 2 | yulara
# Processing Record 21 of Set 2 | port hardy
# Processing Record 22 of Set 2 | samarai
# Processing Record 23 of Set 2 | butaritari
# Processing Record 24 of Set 2 | marsh harbour
# Processing Record 25 of Set 2 | ucluelet
# Processing Record 26 of Set 2 | adrar
# Processing Record 27 of Set 2 | plettenberg bay
# Processing Record 28 of Set 2 | ust-nera
# Processing Record 29 of Set 2 | cayenne
# Processing Record 30 of Set 2 | tuatapere
# Processing Record 31 of Set 2 | luderitz
# Processing Record 32 of Set 2 | hilo
# Processing Record 33 of Set 2 | marawi
# Processing Record 34 of Set 2 | chokurdakh
# Processing Record 35 of Set 2 | severo-kurilsk
# Processing Record 36 of Set 2 | kathu
# Processing Record 37 of Set 2 | camacari
# Processing Record 38 of Set 2 | tiksi
# Processing Record 39 of Set 2 | yakeshi
# Processing Record 40 of Set 2 | maniitsoq
# Processing Record 41 of Set 2 | zyryanka
# Processing Record 42 of Set 2 | norman wells
# Processing Record 43 of Set 2 | ust-maya
# Processing Record 44 of Set 2 | tezu
# Processing Record 45 of Set 2 | gijon
# Processing Record 46 of Set 2 | hasaki
# Processing Record 47 of Set 2 | cabo san lucas
# Processing Record 48 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 2 | henties bay
# Processing Record 50 of Set 2 | valladolid
# Processing Record 1 of Set 3 | atuona
# Processing Record 2 of Set 3 | jalu
# Processing Record 3 of Set 3 | jamestown
# Processing Record 4 of Set 3 | kavieng
# Processing Record 5 of Set 3 | port keats
# Processing Record 6 of Set 3 | palana
# Processing Record 7 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 3 | lata
# Processing Record 9 of Set 3 | kantilo
# Processing Record 10 of Set 3 | quelimane
# Processing Record 11 of Set 3 | hobart
# Processing Record 12 of Set 3 | elat
# Processing Record 13 of Set 3 | hervey bay
# Processing Record 14 of Set 3 | ekhabi
# Processing Record 15 of Set 3 | zhuzhou
# Processing Record 16 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 3 | athabasca
# Processing Record 18 of Set 3 | lastoursville
# Processing Record 19 of Set 3 | quatre cocos
# Processing Record 20 of Set 3 | geraldton
# Processing Record 21 of Set 3 | qaanaaq
# Processing Record 22 of Set 3 | mantua
# Processing Record 23 of Set 3 | sao gabriel da cachoeira
# Processing Record 24 of Set 3 | tunduru
# City not found. Skipping...
# Processing Record 25 of Set 3 | maura
# Processing Record 26 of Set 3 | cartagena
# Processing Record 27 of Set 3 | bambous virieux
# Processing Record 28 of Set 3 | khatanga
# Processing Record 29 of Set 3 | natal
# Processing Record 30 of Set 3 | pisco
# Processing Record 31 of Set 3 | rio grande
# Processing Record 32 of Set 3 | new norfolk
# Processing Record 33 of Set 3 | san patricio
# Processing Record 34 of Set 3 | solginskiy
# Processing Record 35 of Set 3 | homer
# Processing Record 36 of Set 3 | juba
# Processing Record 37 of Set 3 | lanzhou
# Processing Record 38 of Set 3 | nikolskoye
# Processing Record 39 of Set 3 | three hills
# Processing Record 40 of Set 3 | margate
# Processing Record 41 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 3 | doka
# Processing Record 43 of Set 3 | alugan
# Processing Record 44 of Set 3 | ostrovnoy
# Processing Record 45 of Set 3 | madera
# Processing Record 46 of Set 3 | tessalit
# Processing Record 47 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 3 | fortuna
# Processing Record 49 of Set 3 | clyde river
# Processing Record 50 of Set 3 | muriwai beach
# Processing Record 1 of Set 4 | alice springs
# Processing Record 2 of Set 4 | leningradskiy
# Processing Record 3 of Set 4 | rota
# Processing Record 4 of Set 4 | buala
# Processing Record 5 of Set 4 | nicoya
# Processing Record 6 of Set 4 | lavrentiya
# Processing Record 7 of Set 4 | sheopur
# Processing Record 8 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 4 | kupang
# Processing Record 10 of Set 4 | carnarvon
# Processing Record 11 of Set 4 | faanui
# Processing Record 12 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 4 | uzumlu
# City not found. Skipping...
# Processing Record 14 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 4 | vestmannaeyjar
# Processing Record 16 of Set 4 | ribeira grande
# Processing Record 17 of Set 4 | kamaishi
# Processing Record 18 of Set 4 | molo
# Processing Record 19 of Set 4 | apatlaco
# Processing Record 20 of Set 4 | egvekinot
# Processing Record 21 of Set 4 | zhigalovo
# Processing Record 22 of Set 4 | cap malheureux
# Processing Record 23 of Set 4 | katsuura
# Processing Record 24 of Set 4 | los llanos de aridane
# Processing Record 25 of Set 4 | thompson
# Processing Record 26 of Set 4 | srednekolymsk
# Processing Record 27 of Set 4 | golden rock
# City not found. Skipping...
# Processing Record 28 of Set 4 | gizo
# Processing Record 29 of Set 4 | mundo nuevo
# Processing Record 30 of Set 4 | mustasaari
# Processing Record 31 of Set 4 | bengkulu
# Processing Record 32 of Set 4 | corowa
# Processing Record 33 of Set 4 | cidreira
# Processing Record 34 of Set 4 | upernavik
# Processing Record 35 of Set 4 | innisfail
# Processing Record 36 of Set 4 | arawa
# Processing Record 37 of Set 4 | verkh-usugli
# Processing Record 38 of Set 4 | charters towers
# Processing Record 39 of Set 4 | nuuk
# Processing Record 40 of Set 4 | lerwick
# Processing Record 41 of Set 4 | maryville
# Processing Record 42 of Set 4 | port lincoln
# Processing Record 43 of Set 4 | georgetown
# Processing Record 44 of Set 4 | pacific grove
# Processing Record 45 of Set 4 | ibra
# Processing Record 46 of Set 4 | peniche
# Processing Record 47 of Set 4 | kaeo
# Processing Record 48 of Set 4 | santa vitoria
# Processing Record 49 of Set 4 | dekoa
# City not found. Skipping...
# Processing Record 50 of Set 4 | mpika
# Processing Record 1 of Set 5 | la libertad
# Processing Record 2 of Set 5 | oranjemund
# Processing Record 3 of Set 5 | pudem
# Processing Record 4 of Set 5 | hermanus
# Processing Record 5 of Set 5 | bada
# Processing Record 6 of Set 5 | waitati
# Processing Record 7 of Set 5 | zharkent
# Processing Record 8 of Set 5 | salalah
# Processing Record 9 of Set 5 | souillac
# Processing Record 10 of Set 5 | wukari
# Processing Record 11 of Set 5 | qesarya
# Processing Record 12 of Set 5 | bonthe
# Processing Record 13 of Set 5 | portland
# Processing Record 14 of Set 5 | saurimo
# Processing Record 15 of Set 5 | camacha
# Processing Record 16 of Set 5 | castro
# Processing Record 17 of Set 5 | salcedo
# Processing Record 18 of Set 5 | kyra
# Processing Record 19 of Set 5 | ubinskoye
# Processing Record 20 of Set 5 | guerrero negro
# Processing Record 21 of Set 5 | ahipara
# Processing Record 22 of Set 5 | lamar
# Processing Record 23 of Set 5 | tabuk
# Processing Record 24 of Set 5 | namatanai
# Processing Record 25 of Set 5 | toluca
# Processing Record 26 of Set 5 | dunda
# Processing Record 27 of Set 5 | verkhnetulomskiy
# Processing Record 28 of Set 5 | khandyga
# Processing Record 29 of Set 5 | codrington
# Processing Record 30 of Set 5 | umm lajj
# Processing Record 31 of Set 5 | kostomuksha
# Processing Record 32 of Set 5 | oda
# Processing Record 33 of Set 5 | loandjili
# Processing Record 34 of Set 5 | hirara
# Processing Record 35 of Set 5 | makakilo city
# Processing Record 36 of Set 5 | severodvinsk
# Processing Record 37 of Set 5 | taos
# Processing Record 38 of Set 5 | bokspits
# City not found. Skipping...
# Processing Record 39 of Set 5 | puerto cabello
# Processing Record 40 of Set 5 | bethel
# Processing Record 41 of Set 5 | key west
# Processing Record 42 of Set 5 | iqaluit
# Processing Record 43 of Set 5 | aykhal
# Processing Record 44 of Set 5 | saint george
# Processing Record 45 of Set 5 | lazo
# Processing Record 46 of Set 5 | faridan
# City not found. Skipping...
# Processing Record 47 of Set 5 | touros
# Processing Record 48 of Set 5 | ketchikan
# Processing Record 49 of Set 5 | torbay
# Processing Record 50 of Set 5 | lagoa
# Processing Record 1 of Set 6 | east london
# Processing Record 2 of Set 6 | haines junction
# Processing Record 3 of Set 6 | mayya
# Processing Record 4 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 6 | saryg-sep
# Processing Record 6 of Set 6 | wicklow
# Processing Record 7 of Set 6 | buta
# Processing Record 8 of Set 6 | saint-augustin
# Processing Record 9 of Set 6 | trat
# Processing Record 10 of Set 6 | collierville
# Processing Record 11 of Set 6 | high level
# Processing Record 12 of Set 6 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 13 of Set 6 | broome
# Processing Record 14 of Set 6 | zhigansk
# Processing Record 15 of Set 6 | teguldet
# Processing Record 16 of Set 6 | coruripe
# Processing Record 17 of Set 6 | kahului
# Processing Record 18 of Set 6 | manggar
# Processing Record 19 of Set 6 | chima
# Processing Record 20 of Set 6 | pevek
# Processing Record 21 of Set 6 | coolum beach
# Processing Record 22 of Set 6 | sitka
# Processing Record 23 of Set 6 | xochistlahuaca
# Processing Record 24 of Set 6 | alofi
# Processing Record 25 of Set 6 | aljezur
# Processing Record 26 of Set 6 | padang
# Processing Record 27 of Set 6 | havre-saint-pierre
# Processing Record 28 of Set 6 | bowen
# Processing Record 29 of Set 6 | southbridge
# Processing Record 30 of Set 6 | morgan city
# Processing Record 31 of Set 6 | yumen
# Processing Record 32 of Set 6 | faya
# Processing Record 33 of Set 6 | oistins
# Processing Record 34 of Set 6 | mizdah
# Processing Record 35 of Set 6 | valer
# Processing Record 36 of Set 6 | inhambane
# Processing Record 37 of Set 6 | san remo
# Processing Record 38 of Set 6 | husavik
# Processing Record 39 of Set 6 | nouakchott
# Processing Record 40 of Set 6 | palmas
# Processing Record 41 of Set 6 | narsaq
# Processing Record 42 of Set 6 | grindavik
# Processing Record 43 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 6 | san policarpo
# Processing Record 45 of Set 6 | arraial do cabo
# Processing Record 46 of Set 6 | morondava
# Processing Record 47 of Set 6 | darab
# Processing Record 48 of Set 6 | bambanglipuro
# Processing Record 49 of Set 6 | kunya
# Processing Record 50 of Set 6 | agadez
# Processing Record 1 of Set 7 | tabou
# Processing Record 2 of Set 7 | weston-super-mare
# Processing Record 3 of Set 7 | jos
# Processing Record 4 of Set 7 | praya
# Processing Record 5 of Set 7 | saint-louis
# Processing Record 6 of Set 7 | sioux lookout
# Processing Record 7 of Set 7 | macherla
# Processing Record 8 of Set 7 | bocanda
# Processing Record 9 of Set 7 | saint-denis
# Processing Record 10 of Set 7 | morena
# Processing Record 11 of Set 7 | saeby
# Processing Record 12 of Set 7 | champerico
# Processing Record 13 of Set 7 | chimore
# Processing Record 14 of Set 7 | dingle
# Processing Record 15 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 7 | mount pleasant
# Processing Record 17 of Set 7 | kaitangata
# Processing Record 18 of Set 7 | yining
# Processing Record 19 of Set 7 | klaksvik
# Processing Record 20 of Set 7 | correntina
# Processing Record 21 of Set 7 | west bay
# Processing Record 22 of Set 7 | kholodnyy
# Processing Record 23 of Set 7 | puerto cabezas
# Processing Record 24 of Set 7 | marsa matruh
# Processing Record 25 of Set 7 | kavaratti
# Processing Record 26 of Set 7 | bantry
# Processing Record 27 of Set 7 | sandakan
# Processing Record 28 of Set 7 | chamba
# Processing Record 29 of Set 7 | bilma
# Processing Record 30 of Set 7 | longyearbyen
# Processing Record 31 of Set 7 | roald
# Processing Record 32 of Set 7 | zhangjiakou
# Processing Record 33 of Set 7 | chiredzi
# Processing Record 34 of Set 7 | erie
# Processing Record 35 of Set 7 | asau
# Processing Record 36 of Set 7 | bridlington
# Processing Record 37 of Set 7 | tilichiki
# Processing Record 38 of Set 7 | palu
# Processing Record 39 of Set 7 | vardo
# Processing Record 40 of Set 7 | morant bay
# Processing Record 41 of Set 7 | cravo norte
# Processing Record 42 of Set 7 | zinder
# Processing Record 43 of Set 7 | flin flon
# Processing Record 44 of Set 7 | greystones
# Processing Record 45 of Set 7 | bathsheba
# Processing Record 46 of Set 7 | noyabrsk
# Processing Record 47 of Set 7 | viedma
# Processing Record 48 of Set 7 | comodoro rivadavia
# Processing Record 49 of Set 7 | talnakh
# Processing Record 50 of Set 7 | nome
# Processing Record 1 of Set 8 | pekan
# Processing Record 2 of Set 8 | kristiansund
# Processing Record 3 of Set 8 | kieta
# Processing Record 4 of Set 8 | esmeraldas
# Processing Record 5 of Set 8 | san ramon de la nueva oran
# Processing Record 6 of Set 8 | tiznit
# Processing Record 7 of Set 8 | prince rupert
# Processing Record 8 of Set 8 | makarov
# Processing Record 9 of Set 8 | lompoc
# Processing Record 10 of Set 8 | roma
# Processing Record 11 of Set 8 | nabire
# Processing Record 12 of Set 8 | ridgecrest
# Processing Record 13 of Set 8 | pontian kecil
# Processing Record 14 of Set 8 | mahajanga
# Processing Record 15 of Set 8 | oktyabrskiy
# Processing Record 16 of Set 8 | san quintin
# Processing Record 17 of Set 8 | berlevag
# Processing Record 18 of Set 8 | dubbo
# Processing Record 19 of Set 8 | ust-kulom
# Processing Record 20 of Set 8 | hazorasp
# Processing Record 21 of Set 8 | beyneu
# Processing Record 22 of Set 8 | komsomolskiy
# Processing Record 23 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 8 | balikpapan
# Processing Record 25 of Set 8 | baran
# Processing Record 26 of Set 8 | boueni
# Processing Record 27 of Set 8 | batagay
# Processing Record 28 of Set 8 | vila velha
# Processing Record 29 of Set 8 | kindu
# Processing Record 30 of Set 8 | coahuayana
# Processing Record 31 of Set 8 | buon me thuot
# City not found. Skipping...
# Processing Record 32 of Set 8 | ossora
# Processing Record 33 of Set 8 | rawson
# Processing Record 34 of Set 8 | torrox
# Processing Record 35 of Set 8 | okha
# Processing Record 36 of Set 8 | kudahuvadhoo
# Processing Record 37 of Set 8 | huarmey
# Processing Record 38 of Set 8 | afmadu
# City not found. Skipping...
# Processing Record 39 of Set 8 | belmonte
# Processing Record 40 of Set 8 | yerbogachen
# Processing Record 41 of Set 8 | shirokiy
# Processing Record 42 of Set 8 | omboue
# Processing Record 43 of Set 8 | saint cloud
# Processing Record 44 of Set 8 | srandakan
# Processing Record 45 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 47 of Set 8 | antibes
# Processing Record 48 of Set 8 | grand gaube
# Processing Record 49 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 50 of Set 8 | majholi
# Processing Record 1 of Set 9 | ambatolampy
# Processing Record 2 of Set 9 | soyo
# Processing Record 3 of Set 9 | lebu
# Processing Record 4 of Set 9 | lugui
# Processing Record 5 of Set 9 | flagstaff
# Processing Record 6 of Set 9 | vanavara
# Processing Record 7 of Set 9 | sao paulo de olivenca
# Processing Record 8 of Set 9 | antalaha
# Processing Record 9 of Set 9 | olafsvik
# Processing Record 10 of Set 9 | floro
# Processing Record 11 of Set 9 | provideniya
# Processing Record 12 of Set 9 | vila franca do campo
# Processing Record 13 of Set 9 | seddon
# Processing Record 14 of Set 9 | fort nelson
# Processing Record 15 of Set 9 | kangaatsiaq
# Processing Record 16 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 17 of Set 9 | half moon bay
# Processing Record 18 of Set 9 | chicama
# Processing Record 19 of Set 9 | constitucion
# Processing Record 20 of Set 9 | crab hill
# City not found. Skipping...
# Processing Record 21 of Set 9 | denau
# City not found. Skipping...
# Processing Record 22 of Set 9 | abu zabad
# Processing Record 23 of Set 9 | kuytun
# Processing Record 24 of Set 9 | seoul
# Processing Record 25 of Set 9 | barvinkove
# Processing Record 26 of Set 9 | sunrise manor
# Processing Record 27 of Set 9 | havoysund
# Processing Record 28 of Set 9 | hobyo
# Processing Record 29 of Set 9 | kenai
# Processing Record 30 of Set 9 | sovik
# Processing Record 31 of Set 9 | san cristobal
# Processing Record 32 of Set 9 | barahona
# Processing Record 33 of Set 9 | ust-ishim
# Processing Record 34 of Set 9 | nambucca heads
# Processing Record 35 of Set 9 | dunedin
# Processing Record 36 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 9 | denpasar
# Processing Record 38 of Set 9 | tanout
# Processing Record 39 of Set 9 | port macquarie
# Processing Record 40 of Set 9 | tarakan
# Processing Record 41 of Set 9 | batouri
# Processing Record 42 of Set 9 | paita
# Processing Record 43 of Set 9 | kloulklubed
# Processing Record 44 of Set 9 | mitzic
# Processing Record 45 of Set 9 | itinga
# Processing Record 46 of Set 9 | ugep
# Processing Record 47 of Set 9 | almansa
# Processing Record 48 of Set 9 | loa janan
# Processing Record 49 of Set 9 | hualmay
# Processing Record 50 of Set 9 | hays
# Processing Record 1 of Set 10 | ilulissat
# Processing Record 2 of Set 10 | san luis
# Processing Record 3 of Set 10 | sawtell
# Processing Record 4 of Set 10 | meulaboh
# Processing Record 5 of Set 10 | szamotuly
# Processing Record 6 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 7 of Set 10 | okhotsk
# Processing Record 8 of Set 10 | tsumeb
# Processing Record 9 of Set 10 | zenzeli
# Processing Record 10 of Set 10 | akcakoca
# Processing Record 11 of Set 10 | jaciara
# Processing Record 12 of Set 10 | escarcega
# Processing Record 13 of Set 10 | bonito
# Processing Record 14 of Set 10 | harrisonburg
# Processing Record 15 of Set 10 | taoudenni
# Processing Record 16 of Set 10 | channel-port aux basques
# Processing Record 17 of Set 10 | beitbridge
# Processing Record 18 of Set 10 | gabu
# Processing Record 19 of Set 10 | lisakovsk
# Processing Record 20 of Set 10 | osvaldo cruz
# Processing Record 21 of Set 10 | ixtapa
# Processing Record 22 of Set 10 | kristiinankaupunki
# Processing Record 23 of Set 10 | eenhana
# Processing Record 24 of Set 10 | severnoye
# Processing Record 25 of Set 10 | hamilton
# Processing Record 26 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 27 of Set 10 | miraflores
# Processing Record 28 of Set 10 | sao joao da barra
# Processing Record 29 of Set 10 | doha
# Processing Record 30 of Set 10 | te anau
# Processing Record 31 of Set 10 | kelso
# Processing Record 32 of Set 10 | asfi
# Processing Record 33 of Set 10 | lorengau
# Processing Record 34 of Set 10 | pangkalanbuun
# Processing Record 35 of Set 10 | yuancheng
# Processing Record 36 of Set 10 | aloleng
# Processing Record 37 of Set 10 | millau
# Processing Record 38 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 10 | golden
# Processing Record 40 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 10 | krasnogvardeyskiy
# Processing Record 42 of Set 10 | ndouci
# City not found. Skipping...
# Processing Record 43 of Set 10 | la roda
# Processing Record 44 of Set 10 | swan hill
# Processing Record 45 of Set 10 | praia
# Processing Record 46 of Set 10 | lasa
# Processing Record 47 of Set 10 | ankazoabo
# Processing Record 48 of Set 10 | namibe
# Processing Record 49 of Set 10 | qabaqcol
# Processing Record 50 of Set 10 | ballina
# Processing Record 1 of Set 11 | itaituba
# Processing Record 2 of Set 11 | conceicao da barra
# Processing Record 3 of Set 11 | burns lake
# Processing Record 4 of Set 11 | kangasala
# Processing Record 5 of Set 11 | sur
# Processing Record 6 of Set 11 | diamantino
# Processing Record 7 of Set 11 | shar
# Processing Record 8 of Set 11 | cherskiy
# Processing Record 9 of Set 11 | khani
# Processing Record 10 of Set 11 | yar-sale
# Processing Record 11 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 12 of Set 11 | derzhavinsk
# Processing Record 13 of Set 11 | rocha
# Processing Record 14 of Set 11 | waipawa
# Processing Record 15 of Set 11 | kalmunai
# Processing Record 16 of Set 11 | klyuchi
# Processing Record 17 of Set 11 | inta
# Processing Record 18 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 19 of Set 11 | ryotsu
# Processing Record 20 of Set 11 | camapua
# Processing Record 21 of Set 11 | pochutla
# Processing Record 22 of Set 11 | chifeng
# Processing Record 23 of Set 11 | krasnoborsk
# Processing Record 24 of Set 11 | isangel
# Processing Record 25 of Set 11 | maceio
# Processing Record 26 of Set 11 | jiangyou
# Processing Record 27 of Set 11 | nouadhibou
# Processing Record 28 of Set 11 | ancud
# Processing Record 29 of Set 11 | mount isa
# Processing Record 30 of Set 11 | siavonga
# Processing Record 31 of Set 11 | kirakira
# Processing Record 32 of Set 11 | ouro preto do oeste
# Processing Record 33 of Set 11 | taicheng
# Processing Record 34 of Set 11 | tautira
# Processing Record 35 of Set 11 | paamiut
# Processing Record 36 of Set 11 | avera
# Processing Record 37 of Set 11 | tazirkah
# City not found. Skipping...
# Processing Record 38 of Set 11 | cortez
# Processing Record 39 of Set 11 | indramayu
# Processing Record 40 of Set 11 | filingue
# Processing Record 41 of Set 11 | northampton
# Processing Record 42 of Set 11 | rio gallegos
# Processing Record 43 of Set 11 | forestville
# Processing Record 44 of Set 11 | ambulu
# Processing Record 45 of Set 11 | chake chake
# Processing Record 46 of Set 11 | ilek
# Processing Record 47 of Set 11 | erzin
# Processing Record 48 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 49 of Set 11 | iida
# Processing Record 50 of Set 11 | irtyshskiy
# Processing Record 1 of Set 12 | ust-barguzin
# Processing Record 2 of Set 12 | hot springs
# Processing Record 3 of Set 12 | kokkola
# Processing Record 4 of Set 12 | mehran
# Processing Record 5 of Set 12 | guymon
# Processing Record 6 of Set 12 | nueve de julio
# Processing Record 7 of Set 12 | itoman
# Processing Record 8 of Set 12 | campoverde
# Processing Record 9 of Set 12 | sredniy ikorets
# Processing Record 10 of Set 12 | aksu
# Processing Record 11 of Set 12 | yangjiang
# Processing Record 12 of Set 12 | sakakah
# Processing Record 13 of Set 12 | fukue
# Processing Record 14 of Set 12 | atagay
# Processing Record 15 of Set 12 | vanderhoof
# Processing Record 16 of Set 12 | pastavy
# Processing Record 17 of Set 12 | kayes
# Processing Record 18 of Set 12 | aberdeen
# Processing Record 19 of Set 12 | mahon
# Processing Record 20 of Set 12 | savannah bight
# Processing Record 21 of Set 12 | ostoros
# Processing Record 22 of Set 12 | afsin
# Processing Record 23 of Set 12 | kushima
# Processing Record 24 of Set 12 | isparta
# Processing Record 25 of Set 12 | campos
# Processing Record 26 of Set 12 | benicarlo
# Processing Record 27 of Set 12 | redditch
# Processing Record 28 of Set 12 | nexo
# Processing Record 29 of Set 12 | wasilla
# Processing Record 30 of Set 12 | vila do maio
# Processing Record 31 of Set 12 | carutapera
# Processing Record 32 of Set 12 | talakan
# Processing Record 33 of Set 12 | port-gentil
# Processing Record 34 of Set 12 | maralal
# Processing Record 35 of Set 12 | kerema
# Processing Record 36 of Set 12 | muisne
# Processing Record 37 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 38 of Set 12 | tecoanapa
# Processing Record 39 of Set 12 | tretten
# Processing Record 40 of Set 12 | serenje
# Processing Record 41 of Set 12 | goderich
# Processing Record 42 of Set 12 | uyemskiy
# Processing Record 43 of Set 12 | aasiaat
# Processing Record 44 of Set 12 | hami
# Processing Record 45 of Set 12 | wau
# Processing Record 46 of Set 12 | viksoyri
# City not found. Skipping...
# Processing Record 47 of Set 12 | costinesti
# Processing Record 48 of Set 12 | malatya
# Processing Record 49 of Set 12 | ngunguru
# Processing Record 50 of Set 12 | nizwa
# Processing Record 1 of Set 13 | taree
# Processing Record 2 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 3 of Set 13 | xinpu
# Processing Record 4 of Set 13 | otradnoye
# Processing Record 5 of Set 13 | buraydah
# Processing Record 6 of Set 13 | ahuimanu
# Processing Record 7 of Set 13 | arlit
# Processing Record 8 of Set 13 | kamenka
# Processing Record 9 of Set 13 | aklavik
# Processing Record 10 of Set 13 | sheregesh
# Processing Record 11 of Set 13 | williston
# Processing Record 12 of Set 13 | mason city
# Processing Record 13 of Set 13 | thaba-tseka
# Processing Record 14 of Set 13 | kalutara
# Processing Record 15 of Set 13 | playa vicente
# Processing Record 16 of Set 13 | karcsa
# Processing Record 17 of Set 13 | dolinsk
# Processing Record 18 of Set 13 | wulanhaote
# City not found. Skipping...
# Processing Record 19 of Set 13 | morro bay
# Processing Record 20 of Set 13 | muros
# Processing Record 21 of Set 13 | harlingen
# Processing Record 22 of Set 13 | silver city
# Processing Record 23 of Set 13 | puertollano
# Processing Record 24 of Set 13 | mungwi
# Processing Record 25 of Set 13 | sola
# Processing Record 26 of Set 13 | nazilli
# Processing Record 27 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 28 of Set 13 | thinadhoo
# Processing Record 29 of Set 13 | baruun-urt
# Processing Record 30 of Set 13 | laibin
# Processing Record 31 of Set 13 | buchanan
# Processing Record 32 of Set 13 | tahoua
# Processing Record 33 of Set 13 | moree
# Processing Record 34 of Set 13 | blackwater
# Processing Record 35 of Set 13 | sedalia
# Processing Record 36 of Set 13 | gilgil
# City not found. Skipping...
# Processing Record 37 of Set 13 | canton
# Processing Record 38 of Set 13 | chulman
# Processing Record 39 of Set 13 | hsinchu
# Processing Record 40 of Set 13 | manavalakurichi
# Processing Record 41 of Set 13 | lodwar
# Processing Record 42 of Set 13 | gidole
# Processing Record 43 of Set 13 | gorontalo
# Processing Record 44 of Set 13 | bobcaygeon
# Processing Record 45 of Set 13 | leeton
# Processing Record 46 of Set 13 | atasu
# Processing Record 47 of Set 13 | yenagoa
# Processing Record 48 of Set 13 | kakori
# Processing Record 49 of Set 13 | kijang
# Processing Record 50 of Set 13 | birecik
# Processing Record 1 of Set 14 | tamandare
# Processing Record 2 of Set 14 | puerto narino
# Processing Record 3 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 4 of Set 14 | nizhniy baskunchak
# Processing Record 5 of Set 14 | tarko-sale
# Processing Record 6 of Set 14 | richards bay
# Processing Record 7 of Set 14 | belyy yar
# Processing Record 8 of Set 14 | nanning
# Processing Record 9 of Set 14 | larsnes
# Processing Record 10 of Set 14 | nampula
# Processing Record 11 of Set 14 | sinnamary
# Processing Record 12 of Set 14 | parry sound
# Processing Record 13 of Set 14 | ozgon
# City not found. Skipping...
# Processing Record 14 of Set 14 | tura
# Processing Record 15 of Set 14 | port blair
# Processing Record 16 of Set 14 | oudtshoorn
# Processing Record 17 of Set 14 | gotsu
# Processing Record 18 of Set 14 | almaty
# Processing Record 19 of Set 14 | sumkino
# Processing Record 20 of Set 14 | saint-francois
# Processing Record 21 of Set 14 | sokoto
# Processing Record 22 of Set 14 | cabinda
# Processing Record 23 of Set 14 | swinoujscie
# Processing Record 24 of Set 14 | chabahar
# Processing Record 25 of Set 14 | qasigiannguit
# Processing Record 26 of Set 14 | shuiji
# Processing Record 27 of Set 14 | sanary-sur-mer
# Processing Record 28 of Set 14 | marzuq
# Processing Record 29 of Set 14 | mount gambier
# Processing Record 30 of Set 14 | vertientes
# Processing Record 31 of Set 14 | cabra
# Processing Record 32 of Set 14 | tazovskiy
# Processing Record 33 of Set 14 | shima
# Processing Record 34 of Set 14 | itupiranga
# Processing Record 35 of Set 14 | albesti
# Processing Record 36 of Set 14 | linhai
# Processing Record 37 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 38 of Set 14 | ponta delgada
# Processing Record 39 of Set 14 | shubarkuduk
# Processing Record 40 of Set 14 | sambava
# Processing Record 41 of Set 14 | sovetskiy
# Processing Record 42 of Set 14 | sao miguel do araguaia
# Processing Record 43 of Set 14 | talaya
# Processing Record 44 of Set 14 | tucurui
# Processing Record 45 of Set 14 | vidim
# Processing Record 46 of Set 14 | stornoway
# Processing Record 47 of Set 14 | pontianak
# Processing Record 48 of Set 14 | hope
# Processing Record 49 of Set 14 | date
# Processing Record 50 of Set 14 | lufilufi
# Processing Record 1 of Set 15 | san juan
# Processing Record 2 of Set 15 | verkh-chebula
# Processing Record 3 of Set 15 | jiujiang
# Processing Record 4 of Set 15 | del gallego
# Processing Record 5 of Set 15 | casambalangan
# Processing Record 6 of Set 15 | lazaro cardenas
# Processing Record 7 of Set 15 | liepaja
# Processing Record 8 of Set 15 | mackay
# Processing Record 9 of Set 15 | mayo
# Processing Record 10 of Set 15 | burgos
# Processing Record 11 of Set 15 | coihaique
# Processing Record 12 of Set 15 | kharp
# Processing Record 13 of Set 15 | sinjah
# City not found. Skipping...
# Processing Record 14 of Set 15 | pulawy
# Processing Record 15 of Set 15 | akyab
# Processing Record 16 of Set 15 | wentzville
# Processing Record 17 of Set 15 | solnechnyy
# Processing Record 18 of Set 15 | vanimo
# Processing Record 19 of Set 15 | pandelys
# City not found. Skipping...
# Processing Record 20 of Set 15 | puerto suarez
# Processing Record 21 of Set 15 | tuy hoa
# Processing Record 22 of Set 15 | kokopo
# Processing Record 23 of Set 15 | cabedelo
# Processing Record 24 of Set 15 | mokrousovo
# Processing Record 25 of Set 15 | iracoubo
# Processing Record 26 of Set 15 | america dourada
# Processing Record 27 of Set 15 | magadan
# Processing Record 28 of Set 15 | mul
# Processing Record 29 of Set 15 | dutse
# Processing Record 30 of Set 15 | gangapur
# Processing Record 31 of Set 15 | hambantota
# Processing Record 32 of Set 15 | andenes
# Processing Record 33 of Set 15 | mercedes
# Processing Record 34 of Set 15 | san juan evangelista
# Processing Record 35 of Set 15 | labuhan
# Processing Record 36 of Set 15 | kabo
# Processing Record 37 of Set 15 | dali
# Processing Record 38 of Set 15 | adeje
# Processing Record 39 of Set 15 | clarksdale
# Processing Record 40 of Set 15 | eureka
# Processing Record 41 of Set 15 | haimen
# Processing Record 42 of Set 15 | requena
# Processing Record 43 of Set 15 | bakchar
# Processing Record 44 of Set 15 | dauriya
# Processing Record 45 of Set 15 | abonnema
# Processing Record 46 of Set 15 | aden
# Processing Record 47 of Set 15 | turtkul
# City not found. Skipping...
# Processing Record 48 of Set 15 | caravelas
# Processing Record 49 of Set 15 | aquin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
num_cities = len(city_data)
print(num_cities)
# Out:
# 695

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Rikitea -23.1203 -134.9692     79.14        66          14
# 1       Cape Town -33.9258   18.4232     68.11        67          44
# 2           Vaini -21.2000 -175.2000     84.36        84          75
# 3         Ushuaia -54.8000  -68.3000     40.78        88          54
# 4         Mataura -46.1927  168.8643     66.81        56           3
# 5          Dikson  73.5069   80.5464    -17.93       100          21
# 6            Naze  28.3667  129.4833     63.52        58          95
# 7      Wilmington  34.2257  -77.9447     62.85        22           0
# 8  Port Elizabeth -33.9180   25.5701     66.09        99         100
# 9        Victoria  22.2855  114.1577     63.95        94         100
#
#    Wind Speed Country Current Description
# 0        9.44      PF          few clouds
# 1        6.96      ZA    scattered clouds
# 2        5.75      TO       broken clouds
# 3        3.83      AR       broken clouds
# 4        2.62      NZ           clear sky
# 5        3.56      RU          few clouds
# 6       13.73      JP     overcast clouds
# 7       11.50      US           clear sky
# 8        1.01      ZA     overcast clouds
# 9        5.01      HK       moderate rain

# %%
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Rikitea      PF -23.1203 -134.9692     79.14        66          14
# 1    Cape Town      ZA -33.9258   18.4232     68.11        67          44
# 2        Vaini      TO -21.2000 -175.2000     84.36        84          75
# 3      Ushuaia      AR -54.8000  -68.3000     40.78        88          54
# 4      Mataura      NZ -46.1927  168.8643     66.81        56           3
# ..         ...     ...      ...       ...       ...       ...         ...
# 690    Dauriya      RU  49.9333  116.8667     25.21        47          68
# 691   Abonnema      NG   4.7084    6.7931     80.60        83          37
# 692       Aden      YE  12.7794   45.0367     80.13        61           5
# 693  Caravelas      BR -17.7125  -39.2481     76.17        83           0
# 694      Aquin      HT  18.2833  -73.4000     77.94        73          72
#
#      Wind Speed Current Description
# 0          9.44          few clouds
# 1          6.96    scattered clouds
# 2          5.75       broken clouds
# 3          3.83       broken clouds
# 4          2.62           clear sky
# ..          ...                 ...
# 690        4.59       broken clouds
# 691        5.26    scattered clouds
# 692        3.18           clear sky
# 693        5.10           clear sky
# 694       10.18       broken clouds
#
# [695 rows x 9 columns]

# %%
# Create the output file (CSV)
output_data_file = "../WeatherPy_Database.csv"
# Export the City_Data into CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
